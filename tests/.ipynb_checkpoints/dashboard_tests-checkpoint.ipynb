# %%
from dashboard import TrainingDashboard

# %%
monitor = TrainingDashboard("./output/run_20260503_125911", refresh_rate = 0.5)
monitor.run(port = 8053)
# Out:
# Monitoring run: output/run_20260503_125911
# Monitoring host: http://localhost:8053
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8053/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
