# %%
import numpy as np
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit
from qiskit.visualization import plot_histogram

# %%
from qgan_lamarr import QGAN, MinMaxBinning, SingleGaussian
# Out:
# 2026-05-06 10:29:48.292341: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-06 10:29:48.319539: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778056188.336302  181653 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778056188.340652  181653 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778056188.354879  181653 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778056188.354912  181653 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778056188.354914  181653 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778056188.354916  181653 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-06 10:29:48.359869: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Distribution embedding

# %%
num_qubits = 3
nbins = 2**num_qubits

def sample_dist(_size, _nbins):
    _sample = SingleGaussian(shots = _size)
    return MinMaxBinning(_sample, _nbins)

sample = sample_dist(2**10, nbins)
print(sample)
plot_histogram(sample)
# Out:
# {'000': 10, '001': 72, '010': 177, '011': 322, '100': 268, '101': 136, '110': 35, '111': 4}

# %% [markdown]
# # QGAN evaluation

# %%
from qiskit.circuit import ParameterVector

reps = 2
qc = QuantumCircuit(num_qubits)
qc.h(range(num_qubits))
theta = ParameterVector("θ", length = (reps + 1) * num_qubits * 2)

p = 0

for q in range(num_qubits):
        qc.ry(theta[q], q)
        p += 1
for r in range(reps):

    for q in range(num_qubits):
        qc.cz(q%num_qubits, (q + 1)%num_qubits)
    for q in range(num_qubits):
        qc.ry(theta[p], q)
        p += 1
        
    

qc.draw("mpl")

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, LeakyReLU

discriminator = Sequential([
    InputLayer(shape=(nbins,)),
    Dense(50),
    LeakyReLU(),
    Dense(1, activation='linear') 
])

discriminator.summary()
# Out:
# 2026-05-06 10:29:54.423655: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 50)             │           450 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 501 (1.96 KB)
#  Trainable params: 501 (1.96 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model = QGAN(num_qubits =int(np.log2(nbins)),
             generator = qc,
             discriminator = discriminator,
             real_dist = sample_dist,
             wass = True)

# %%
epochs = 2000
model.discriminator_lr = 1e-4
model.fit(epochs = epochs, shots = 2**10, step_balance = 5.0, manager = True, opt = 'ADAM_PSR', lr = 1e-3)
# Out:
# Monitoring run: run_20260506_102954
# Training started
#   1%|          | 16/2000 [00:08<17:14,  1.92it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 epochs = 2000
#       2 model.discriminator_lr = 1e-4
# ----> 3 model.fit(epochs = epochs, shots = 2**10, step_balance = 5.0, manager = True, opt = 'ADAM_PSR', lr = 1e-3)
#
# File ~/qgan-lamarr/qgan-lamarr/qgan_lamarr/models.py:229, in QGAN.fit(self, epochs, step_balance, shots, initial_weights, manager, opt, **opt_args)
#     225 for stp in tqdm(range(epochs)):
#     226
#     227     # Train discriminator
#     228     for _ in range(int(np.ceil(step_balance))):
# --> 229         d_loss_val = self.train_discriminator(weights_gen)
#     230     self.discriminator_losses.append(d_loss_val)
#     232     # Train generator
#
# File ~/qgan-lamarr/qgan-lamarr/qgan_lamarr/models.py:178, in QGAN.train_discriminator(self, weights_gen)
#     174 '''
#     175     One gradient update step for the discriminator
#     176 '''
#     177 with tf.GradientTape() as tape:
# --> 178     d_loss = self.discriminator_loss(weights_gen)
#     180 grads = tape.gradient(d_loss, self._discriminator.trainable_variables)
#     181 self._discriminator_optimizer.apply_gradients(zip(grads, self._discriminator.trainable_variables))
#
# File ~/qgan-lamarr/qgan-lamarr/qgan_lamarr/models.py:135, in QGAN.discriminator_loss(self, weights_gen)
#     131 '''
#     132 Wasserstein loss with Gradient Penalty: D(G(z)) - D(x) + lambda * GP
#     133 '''
#     134 fake_sample = self.generator_eval(weights_gen)
# --> 135 real_sample = self.real_dist_eval()
#     137 x_fake = tf.convert_to_tensor(dict2vector(fake_sample, self._bins)[None, :])
#     138 x_real = tf.convert_to_tensor(dict2vector(real_sample, self._bins)[None, :])
#
# File ~/qgan-lamarr/qgan-lamarr/qgan_lamarr/models.py:92, in QGAN.real_dist_eval(self)
#      88 def real_dist_eval(self) -> dict:
#      89     '''
#      90         Samples the real distribution
#      91     '''
# ---> 92     return self._real_dist(self._nshots, self._dim)
#
# Cell In[3], line 6, in sample_dist(_size, _nbins)
#       4 def sample_dist(_size, _nbins):
#       5     _sample = SingleGaussian(shots = _size)
# ----> 6     return MinMaxBinning(_sample, _nbins)
#
# File ~/qgan-lamarr/qgan-lamarr/qgan_lamarr/distributions.py:35, in MinMaxBinning(_data, _nbins)
#      32 bin_min_val = min(_data) + bin_length * b
#      33 bin_max_val = min(_data) + bin_length * (b+1)
# ---> 35 bin_counts = sum(1 for x in _data if bin_min_val <= x < bin_max_val)
#      36 if b == _nbins-1:
#      37     bin_counts += sum(1 for x in _data if x == bin_max_val)
#
# File ~/qgan-lamarr/qgan-lamarr/qgan_lamarr/distributions.py:35, in <genexpr>(.0)
#      32 bin_min_val = min(_data) + bin_length * b
#      33 bin_max_val = min(_data) + bin_length * (b+1)
# ---> 35 bin_counts = sum(1 for x in _data if bin_min_val <= x < bin_max_val)
#      36 if b == _nbins-1:
#      37     bin_counts += sum(1 for x in _data if x == bin_max_val)
#
# KeyboardInterrupt:

# %%
baseline_js, baseline_js_std = model.compute_baseline_js(n_samples = 100)
print(f"Sampling Noise Floor (JS Baseline): {baseline_js:.4f}({baseline_js_std:.4f})")

# %%
plt.plot(model.generator_losses, label = 'generator')
plt.plot(model.discriminator_losses, label = 'discriminator')
plt.legend()
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(model.metrics['jensen_shannon'], label = 'jensen_shannon')
plt.plot([0,epochs-1],[baseline_js,baseline_js])
plt.legend()
plt.xlabel('epoch')
plt.show()

# %%
nsamples = 2**10
gen_res = model.get_sample(nsamples)
real_res = sample_dist(nsamples, nbins)
plot_histogram([gen_res, real_res], legend = ["generated","real sample"])
