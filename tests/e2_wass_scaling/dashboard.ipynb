# %%
import sys
sys.path.insert(1, '/home/fredo/qgan-lamarr/qgan_tests')
from dashboard import TrainingDashboard
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776667664.028387     797 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776667664.072789     797 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776667664.535923     797 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776667664.535975     797 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776667664.535976     797 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
monitor = TrainingDashboard("./output/run_20260420_105326", refresh_rate = 0.5)
monitor.run(port = 8055)
# Out:
# Monitoring run: output/run_20260420_105326
# Monitoring host: http://localhost:8055
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8055/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
