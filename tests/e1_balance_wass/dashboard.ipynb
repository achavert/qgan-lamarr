# %%
import sys
sys.path.insert(1, '/home/fredo/qgan-lamarr/qgan_tests')
from dashboard import TrainingDashboard
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776445216.822308 1115982 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776445216.845518 1115982 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776445216.904767 1115982 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776445216.904807 1115982 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776445216.904810 1115982 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
monitor = TrainingDashboard("./output/wqgan_d4_g3_b10", refresh_rate = 0.5)
monitor.run(port = 8054)
# Out:
# Monitoring run: output/wqgan_d4_g3_b10
# Monitoring host: http://localhost:8054
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
